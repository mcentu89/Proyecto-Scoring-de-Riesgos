# %% [markdown]
# # PLANTILLA EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = r'C:\Users\mcent\OneDrive\Escritorio\PROYECTOS ML\SCORING_DE_RIESGOS'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %%
num
# Out:
#             ingresos    dti  num_hipotecas  num_lineas_credito  \
# id_cliente
# 137387967    54000.0  19.31              2                  10
# 4798121      65000.0  25.40              1                  15
# 87998444    188000.0  11.69              3                  15
# 132883631   125000.0   9.00              1                   6
# 77861711     50000.0  29.31              1                   8
# ...              ...    ...            ...                 ...
# 144538772   200000.0   5.57              2                  11
# 73222117     85000.0  33.05              1                  25
# 129396054    55000.0  15.36              1                   7
# 51876926     42000.0  20.85              6                   9
# 53664762    168000.0   4.69              0                   8
#
#             porc_tarjetas_75p  porc_uso_revolving  num_cancelaciones_12meses  \
# id_cliente
# 137387967                33.3                45.2                          0
# 4798121                  85.7                86.2                          0
# 87998444                  0.0                 3.3                          0
# 132883631                33.3                69.9                          0
# 77861711                  0.0                40.8                          0
# ...                       ...                 ...                        ...
# 144538772                75.0                64.7                          0
# 73222117                 90.0                76.0                          1
# 129396054                75.0                81.7                          0
# 51876926                100.0                81.6                          0
# 53664762                  0.0                52.4                          0
#
#             num_derogatorios  num_meses_desde_ult_retraso  principal  \
# id_cliente
# 137387967                  0                           10    15000.0
# 4798121                    0                            0    10000.0
# 87998444                   0                            0    27000.0
# 132883631                  0                           16    22000.0
# 77861711                   0                            8    14400.0
# ...                      ...                          ...        ...
# 144538772                  0                           30    25000.0
# 73222117                   0                            0     3000.0
# 129396054                  0                            0    14400.0
# 51876926                   0                           13     8000.0
# 53664762                   2                            0    30050.0
#
#             tipo_interes  imp_cuota  imp_amortizado  imp_recuperado
# id_cliente
# 137387967           7.21     464.60         2669.06            0.00
# 4798121            17.77     360.38         6362.96            0.00
# 87998444            8.99     560.35        12443.00            0.00
# 132883631          10.90     719.22        22000.00            0.00
# 77861711           15.31     501.37         2310.49         6430.36
# ...                  ...        ...             ...             ...
# 144538772          11.80     827.98         1763.67            0.00
# 73222117            9.75      96.45         3000.00            0.00
# 129396054          17.47     361.53         1975.94            0.00
# 51876926           12.29     266.83         8000.00            0.00
# 53664762           18.25     767.17         2964.44         2750.88
#
# [128566 rows x 14 columns]

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
variables = ['antiguedad_empleo', 'ingresos_verificados', 'rating',
       'vivienda','finalidad', 'num_cuotas', 'estado']

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat[variables].apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
temp = frecuencias_cat(cat)
temp
# Out:
#                 Variable                                              Valor  \
# 9      antiguedad_empleo                                            9 years
# 7      antiguedad_empleo                                            7 years
# 8      antiguedad_empleo                                            8 years
# 6      antiguedad_empleo                                            6 years
# 4      antiguedad_empleo                                            4 years
# 5      antiguedad_empleo                                            5 years
# 0      antiguedad_empleo                                             1 year
# 10     antiguedad_empleo                                           < 1 year
# 3      antiguedad_empleo                                            3 years
# 2      antiguedad_empleo                                            2 years
# 1      antiguedad_empleo                                          10+ years
# 44                estado                                            Default
# 45                estado  Does not meet the credit policy. Status:Charge...
# 46                estado  Does not meet the credit policy. Status:Fully ...
# 49                estado                                  Late (16-30 days)
# 48                estado                                    In Grace Period
# 50                estado                                 Late (31-120 days)
# 42                estado                                        Charged Off
# 43                estado                                            Current
# 47                estado                                         Fully Paid
# 29             finalidad                                        educational
# 36             finalidad                                   renewable_energy
# 39             finalidad                                            wedding
# 31             finalidad                                              house
# 34             finalidad                                             moving
# 38             finalidad                                           vacation
# 26             finalidad                                                car
# 37             finalidad                                     small_business
# 33             finalidad                                            medical
# 32             finalidad                                     major_purchase
# 35             finalidad                                              other
# 30             finalidad                                   home_improvement
# 27             finalidad                                        credit_card
# 28             finalidad                                 debt_consolidation
# 13  ingresos_verificados                                           Verified
# 11  ingresos_verificados                                       Not Verified
# 12  ingresos_verificados                                    Source Verified
# 41            num_cuotas                                          60 months
# 40            num_cuotas                                          36 months
# 20                rating                                                  G
# 19                rating                                                  F
# 18                rating                                                  E
# 17                rating                                                  D
# 14                rating                                                  A
# 16                rating                                                  C
# 15                rating                                                  B
# 23              vivienda                                              OTHER
# 21              vivienda                                                ANY
# 24              vivienda                                                OWN
# 25              vivienda                                               RENT
# 22              vivienda                                           MORTGAGE
#
#     Frecuencia
# 9     0.037553
# 7     0.043783
# 8     0.044320
# 6     0.048528
# 4     0.065126
# 5     0.067008
# 0     0.071069
# 10    0.085232
# 3     0.086430
# 2     0.096620
# 1     0.354332
# 44    0.000023
# 45    0.000373
# 46    0.000871
# 49    0.001913
# 48    0.003780
# 50    0.009552
# 42    0.117208
# 43    0.382208
# 47    0.484070
# 29    0.000148
# 36    0.000591
# 39    0.001104
# 31    0.006479
# 34    0.006868
# 38    0.007179
# 26    0.010042
# 37    0.010920
# 33    0.011838
# 32    0.022253
# 35    0.060553
# 30    0.064768
# 27    0.226802
# 28    0.570454
# 13    0.260341
# 11    0.333409
# 12    0.406250
# 41    0.293258
# 40    0.706742
# 20    0.005834
# 19    0.018753
# 18    0.060903
# 17    0.142814
# 14    0.191357
# 16    0.286592
# 15    0.293748
# 23    0.000101
# 21    0.000303
# 24    0.104157
# 25    0.401062
# 22    0.494376

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12)
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat[variables])

# %% [markdown]
# **Conclusiones:**
#
# En transformación:
#
# * En vivienda juntar ANY, NONE y OTHER a la categoria mayoritaria
# * En finalidad juntar renewable_energy, educational y wedding en 'otros'
# * Crear la target a partir de estado

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                                 count          mean     median           std  \
# ingresos                     128566.0  76988.946995  67000.000  42281.927241
# dti                          128566.0     18.513956     17.740      9.240860
# num_hipotecas                128566.0      1.513791      1.000      1.886214
# num_lineas_credito           128566.0     11.728155     11.000      5.660315
# porc_tarjetas_75p            128566.0     41.383578     33.300     36.348939
# porc_uso_revolving           128566.0     50.696284     50.800     24.567385
# num_cancelaciones_12meses    128566.0      0.008649      0.000      0.103318
# num_derogatorios             128566.0      0.192804      0.000      0.566427
# num_meses_desde_ult_retraso  128566.0     16.798073      0.000     22.941315
# principal                    128566.0  15176.203662  13000.000   9151.712059
# tipo_interes                 128566.0     13.095348     12.620      4.833173
# imp_cuota                    128566.0    449.261045    382.865    266.112180
# imp_amortizado               128566.0   9696.101449   7200.000   8332.275601
# imp_recuperado               128566.0    148.502480      0.000    768.608162
#
#                                   min         25%        50%       75%  \
# ingresos                     12000.00  48000.0000  67000.000  95000.00
# dti                             -1.00     11.9800     17.740     24.32
# num_hipotecas                    0.00      0.0000      1.000      2.00
# num_lineas_credito               1.00      8.0000     11.000     15.00
# porc_tarjetas_75p                0.00      0.0000     33.300     66.70
# porc_uso_revolving               0.00     32.1000     50.800     69.70
# num_cancelaciones_12meses        0.00      0.0000      0.000      0.00
# num_derogatorios                 0.00      0.0000      0.000      0.00
# num_meses_desde_ult_retraso      0.00      0.0000      0.000     30.00
# principal                      500.00   8000.0000  13000.000  20000.00
# tipo_interes                     5.31      9.4900     12.620     15.99
# imp_cuota                        7.61    256.0100    382.865    595.52
# imp_amortizado                   0.00   3164.3325   7200.000  14000.00
# imp_recuperado                   0.00      0.0000      0.000      0.00
#
#                                    max
# ingresos                     300000.00
# dti                             181.88
# num_hipotecas                    27.00
# num_lineas_credito               84.00
# porc_tarjetas_75p               100.00
# porc_uso_revolving              100.00
# num_cancelaciones_12meses         5.00
# num_derogatorios                 46.00
# num_meses_desde_ult_retraso     145.00
# principal                     40000.00
# tipo_interes                     30.99
# imp_cuota                      1607.80
# imp_amortizado                40000.00
# imp_recuperado                33666.34

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# Vamos a analizar el detalle de imp_amortizado e imp_recuperado, ya que son relevantes para la target del modelo LGD.

# %%
ratios = num[['principal','imp_amortizado','imp_recuperado']].copy()

# %%
ratios['r_amortizado_principal'] = ratios.imp_amortizado / ratios.principal
ratios['r_recuperado_principal'] = ratios.imp_recuperado / ratios.principal

# %%
ratios.describe().T
# Out:
#                            count          mean          std    min  \
# principal               128566.0  15176.203662  9151.712059  500.0
# imp_amortizado          128566.0   9696.101449  8332.275601    0.0
# imp_recuperado          128566.0    148.502480   768.608162    0.0
# r_amortizado_principal  128566.0      0.669511     0.367023    0.0
# r_recuperado_principal  128566.0      0.009028     0.041153    0.0
#
#                                25%           50%      75%           max
# principal               8000.00000  13000.000000  20000.0  40000.000000
# imp_amortizado          3164.33250   7200.000000  14000.0  40000.000000
# imp_recuperado             0.00000      0.000000      0.0  33666.340000
# r_amortizado_principal     0.28493      0.908497      1.0      1.000032
# r_recuperado_principal     0.00000      0.000000      0.0      1.220774

# %% [markdown]
# **Conclusiones:**
#
# * En transformación convertir num_derogatorios a binaria
# * Revisar en profundidad la relación entre estado e imp_recuperado
# * Convertir porc_tarjetas_75p en una variable discreta

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
